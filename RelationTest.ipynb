# %%
from reframe import Relation

country = Relation('country.csv')

# %%
country.query('continent == "Antarctica"').project(['code','name']).cartesian_product(country.query('continent == "Antarctica"').project(['code','name']))
# Out:
#    code_x                                        name_x code_y  \
# 0     ATA                                    Antarctica    ATA
# 1     ATA                                    Antarctica    BVT
# 2     ATA                                    Antarctica    SGS
# 3     ATA                                    Antarctica    HMD
# 4     ATA                                    Antarctica    ATF
# 5     BVT                                 Bouvet Island    ATA
# 6     BVT                                 Bouvet Island    BVT
# 7     BVT                                 Bouvet Island    SGS
# 8     BVT                                 Bouvet Island    HMD
# 9     BVT                                 Bouvet Island    ATF
# 10    SGS  South Georgia and the South Sandwich Islands    ATA
# 11    SGS  South Georgia and the South Sandwich Islands    BVT
# 12    SGS  South Georgia and the South Sandwich Islands    SGS
# 13    SGS  South Georgia and the South Sandwich Islands    HMD
# 14    SGS  South Georgia and the South Sandwich Islands    ATF
# 15    HMD             Heard Island and McDonald Islands    ATA
# 16    HMD             Heard Island and McDonald Islands    BVT
# 17    HMD             Heard Island and McDonald Islands    SGS
# 18    HMD             Heard Island and McDonald Islands    HMD
# 19    HMD             Heard Island and McDonald Islands    ATF
# 20    ATF                   French Southern territories    ATA
# 21    ATF                   French Southern territories    BVT
# 22    ATF                   French Southern territories    SGS
# 23    ATF                   French Southern territories    HMD
# 24    ATF                   French Southern territories    ATF
#
#                                           name_y
# 0                                     Antarctica
# 1                                  Bouvet Island
# 2   South Georgia and the South Sandwich Islands
# 3              Heard Island and McDonald Islands
# 4                    French Southern territories
# 5                                     Antarctica
# 6                                  Bouvet Island
# 7   South Georgia and the South Sandwich Islands
# 8              Heard Island and McDonald Islands
# 9                    French Southern territories
# 10                                    Antarctica
# 11                                 Bouvet Island
# 12  South Georgia and the South Sandwich Islands
# 13             Heard Island and McDonald Islands
# 14                   French Southern territories
# 15                                    Antarctica
# 16                                 Bouvet Island
# 17  South Georgia and the South Sandwich Islands
# 18             Heard Island and McDonald Islands
# 19                   French Southern territories
# 20                                    Antarctica
# 21                                 Bouvet Island
# 22  South Georgia and the South Sandwich Islands
# 23             Heard Island and McDonald Islands
# 24                   French Southern territories

# %%
country.groupby('continent').count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-790c2844d6cd> in <module>()
# ----> 1 country.groupby('continent').count()
#
# /Users/millbr02/src/reframe/reframe.py in groupby(self, cols)
#      44     def groupby(self,cols):
#      45         res = super().groupby(cols)
# ---> 46         return GroupWrap(res)
#      47
#      48
#
# /Users/millbr02/Environments/jupyter/lib/python3.5/site-packages/pandas/core/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze)
#     414         if grouper is None:
#     415             grouper, exclusions, obj = _get_grouper(obj, keys, axis=axis,
# --> 416                                                     level=level, sort=sort)
#     417
#     418         self.obj = obj
#
# /Users/millbr02/Environments/jupyter/lib/python3.5/site-packages/pandas/core/groupby.py in _get_grouper(obj, key, axis, level, sort)
#    2076     """
#    2077
# -> 2078     group_axis = obj._get_axis(axis)
#    2079
#    2080     # validate that the passed level is compatible with the passed
#
# /Users/millbr02/Environments/jupyter/lib/python3.5/site-packages/pandas/core/groupby.py in __getattr__(self, attr)
#     552             return self[attr]
#     553         if hasattr(self.obj, attr):
# --> 554             return self._make_wrapper(attr)
#     555
#     556         raise AttributeError("%r object has no attribute %r" %
#
# /Users/millbr02/Environments/jupyter/lib/python3.5/site-packages/pandas/core/groupby.py in _make_wrapper(self, name)
#     569                    "using the 'apply' method".format(kind, name,
#     570                                                      type(self).__name__))
# --> 571             raise AttributeError(msg)
#     572
#     573         # need to setup the selection
#
# AttributeError: Cannot access callable attribute '_get_axis' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %%
country.groupby(['continent','region']).count().reset_index()

# %%
country.groupby('continent')

# %%
import pandas as pd

# %%
type(pd.core.groupby.DataFrameGroupBy)
